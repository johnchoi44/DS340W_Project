# %% [markdown]
# ## load packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## load data

# %%
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/MyDrive/ds340/nypd complaint data/final_data.csv')

df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Unnamed: 0  index  zipcode  num_felony  num_violation  num_misdemeanor  \
# 0           0      0  10001.0        2918            734             3677
# 1           1      1  10002.0        2278           1024             4381
# 2           2      2  10003.0        1865            453             3066
# 3           3      3  10004.0         143             70              229
# 4           4      4  10005.0         219             76              963
#
#   most_freq_ofns_desc most_freq_loc_occur most_freq_prem_type  \
# 0       PETIT LARCENY              INSIDE              STREET
# 1       PETIT LARCENY              INSIDE              STREET
# 2       PETIT LARCENY              INSIDE              STREET
# 3       PETIT LARCENY              INSIDE              STREET
# 4       PETIT LARCENY              INSIDE         CHAIN STORE
#
# ...

# %%
# check number of rows and columns in final data
df.shape
# Out:
# (179, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                179 non-null    int64
#  1   index                     179 non-null    int64
#  2   zipcode                   178 non-null    float64
#  3   num_felony                179 non-null    int64
#  4   num_violation             179 non-null    int64
#  5   num_misdemeanor           179 non-null    int64
#  6   most_freq_ofns_desc       179 non-null    object
#  7   most_freq_loc_occur       179 non-null    object
#  8   most_freq_prem_type       179 non-null    object
#  9   most_freq_susp_age_group  179 non-null    object
#  10  most_freq_susp_race       179 non-null    object
#  11  most_freq_susp_sex        179 non-null    object
#  12  most_freq_vic_age_group   179 non-null    object
# ...

# %%
# we can observe null values in 'zipcode', 'median_income', 'unemployment_rate'
null_zipcode = df[df['zipcode'].isnull()]
null_income = df[df['median_income'].isnull()]
null_unemployment = df[df['unemployment_rate'].isnull()]

print(null_zipcode)
print(null_income)
print(null_unemployment)
# Out:
#      Unnamed: 0  index  zipcode  num_felony  num_violation  num_misdemeanor  \
# 178         178    178      NaN          18              6               39
#
#     most_freq_ofns_desc most_freq_loc_occur most_freq_prem_type  \
# 178       PETIT LARCENY              INSIDE              STREET
#
#     most_freq_susp_age_group most_freq_susp_race most_freq_susp_sex  \
# 178                  UNKNOWN             UNKNOWN                  M
#
#     most_freq_vic_age_group most_freq_vic_race most_freq_vic_sex  \
# 178                   25-44              BLACK                 F
#
#      num_total_crimes  median_income  unemployment_rate  num_stopandfrisk  \
# 178                63            NaN                NaN                 0
#
#      num_police_station  num_restroom
# 178                   0             0
#      Unnamed: 0  index  zipcode  num_felony  num_violation  num_misdemeanor  \
# 177         177    177  99999.0         493            216              747
# ...
